# %%
import pandas as pd
import numpy as np
import seaborn as snp
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Dell\Desktop\Priyanshi_Python_notepade_jupeter_work\Statistics_Python\Exploratory_Data_Analysis_Project\Project_1\hotel_bookings.csv')
pd.set_option("display.max_columns",None)
# pd.set_option("display.max_row",None)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
col=df.select_dtypes([int,float])
col
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
per=col.isnull().sum()/col.shape[0]*100
per
# Out:
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# booking_changes                    0.000000
# agent                             13.686238
# company                           94.306893
# days_in_waiting_list               0.000000
# adr                                0.000000
# required_car_parking_spaces        0.000000
# total_of_special_requests          0.000000
# dtype: float64

# %%
col_name=per[per>0].keys()
col_name
# Out:
# Index(['children', 'agent', 'company'], dtype='object')

# %%
df_1=df.loc[:,col_name].mean()
df_1
# Out:
# children      0.103890
# agent        86.693382
# company     189.266735
# dtype: float64

# %%
df_copy=df.fillna(df_1)
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_copy[['children','agent','company','adr']]=df_copy[['children','agent','company','adr']].astype('int')
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  int32
#  11  babies                          119390 non-null  int64
# ...

# %%
df_copy
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# 1. How Many Booking Were Cancelled?(Using each class)

df_copy['is_canceled'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
CB=df_copy[df_copy.loc[:,'is_canceled']==1]
CB
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
CB['is_canceled'].count()
# Out:
# 44224

# %%
# 2. What is the booking ratio between Resort Hotel and City Hotel?

df_copy['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
# Resort Hotel:
RH=df_copy[df_copy.loc[:,'hotel']=='Resort Hotel']
RH
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
# City Hotel:

CH=df_copy[df_copy.loc[:,'hotel']=='City Hotel']
CH
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
df_copy['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
# 3. What is the percentage of booking for each year?

df_copy['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int64)

# %%
year=df_copy['arrival_date_year'].value_counts()
year
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
# 4. Which is the most busy month for hotel?

df_copy['arrival_date_month'].unique()
# Out:
# array(['July', 'August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June'],
#       dtype=object)

# %%
month=df_copy['arrival_date_month'].value_counts()
month
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
# 5. From which country most guest come?

df_copy['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
country=df_copy['country'].value_counts()
country
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
# 6. How Long People Stay in the hotel?

df_copy['lead_time'].unique()
# Out:
# array([342, 737,   7,  13,  14,   0,   9,  85,  75,  23,  35,  68,  18,
#         37,  12,  72, 127,  78,  48,  60,  77,  99, 118,  95,  96,  69,
#         45,  40,  15,  36,  43,  70,  16, 107,  47, 113,  90,  50,  93,
#         76,   3,   1,  10,   5,  17,  51,  71,  63,  62, 101,   2,  81,
#        368, 364, 324,  79,  21, 109, 102,   4,  98,  92,  26,  73, 115,
#         86,  52,  29,  30,  33,  32,   8, 100,  44,  80,  97,  64,  39,
#         34,  27,  82,  94, 110, 111,  84,  66, 104,  28, 258, 112,  65,
#         67,  55,  88,  54, 292,  83, 105, 280, 394,  24, 103, 366, 249,
#         22,  91,  11, 108, 106,  31,  87,  41, 304, 117,  59,  53,  58,
#        116,  42, 321,  38,  56,  49, 317,   6,  57,  19,  25, 315, 123,
#         46,  89,  61, 312, 299, 130,  74, 298, 119,  20, 286, 136, 129,
#        124, 327, 131, 460, 140, 114, 139, 122, 137, 126, 120, 128, 135,
#        150, 143, 151, 132, 125, 157, 147, 138, 156, 164, 346, 159, 160,
# ...

# %%
lead_time=df_copy['lead_time'].value_counts()
lead_time
# Out:
# lead_time
# 0      6345
# 1      3460
# 2      2069
# 3      1816
# 4      1715
#        ...
# 400       1
# 370       1
# 532       1
# 371       1
# 463       1
# Name: count, Length: 479, dtype: int64

# %%
# 7. Which was the most booked accommodation type (Single, Couple, Family)?
